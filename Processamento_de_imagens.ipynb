# %% [markdown]
# <a href="https://colab.research.google.com/github/AlineLGo/Machine_Leaning/blob/master/Processamento_de_imagens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 #OpenCV
import numpy as np # bibilioteca que trabalha com matriz
from matplotlib import pyplot as plt # trabalha com gráficos
from google.colab.patches import cv2_imshow # mostrar as imagens utilizando OpenCV

# %%
img = cv2.imread('/content/drive/MyDrive/Curso de Machine Learning/paisagem.jpg')
plt.imshow(img) # traz a imagem no formato BGR

# %%
# Fazendo a conversão da imagem para RGB
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb) # inverte os valores para cada pixel

# %%
# Transformando para tons de cinza
gray = cv2.cvtColor(rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap='gray')

# %%
limiar = 100 # 0 -255

# %%
val, thresh = cv2.threshold(gray, limiar, 255, cv2.THRESH_BINARY)

# %%
val
# Out:
# 100.0

# %%
plt.imshow(thresh,cmap='gray')

# %%
limiar = 162 #@param {type: "slider", min: 0, max: 255, step:1}
val, thresh = cv2.threshold(gray, limiar, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, cmap='gray');
